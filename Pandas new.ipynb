# %%
import pandas as pd

# %% [markdown]
# # **DataSet loading**

# %%
data=pd.read_csv("titanic.csv")
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0.0     3.0    male  22.0    1.0    0.0   7.2500        S   Third
# 1         1.0     1.0     NaN  38.0    1.0    0.0  71.2833        C   First
# 2         1.0     3.0  female  26.0    0.0    0.0   7.9250        S   Third
# 3         1.0     1.0  female  35.0    1.0    0.0  53.1000        S   First
# 4         0.0     3.0    male   NaN    0.0    0.0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886       0.0     2.0    male  27.0    0.0    0.0  13.0000        S  Second
# 887       1.0     1.0  female  19.0    0.0    0.0  30.0000        S   First
# 888       0.0     3.0  female   NaN    1.0    2.0  23.4500        S   Third
# 889       1.0     1.0    male  26.0    0.0    0.0  30.0000        C   First
# 890       0.0     3.0    male  32.0    0.0    0.0   7.7500        Q   Third
#
#        who adult_male deck  embark_town alive  alone
# ...

# %%
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0.0     3.0    male  22.0    1.0    0.0   7.2500        S   Third
# 1         1.0     1.0     NaN  38.0    1.0    0.0  71.2833        C   First
# 2         1.0     3.0  female  26.0    0.0    0.0   7.9250        S   Third
# 3         1.0     1.0  female  35.0    1.0    0.0  53.1000        S   First
# 4         0.0     3.0    male   NaN    0.0    0.0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886       0.0     2.0    male  27.0    0.0    0.0  13.0000        S  Second
# 887       1.0     1.0  female  19.0    0.0    0.0  30.0000        S   First
# 888       0.0     3.0  female   NaN    1.0    2.0  23.4500        S   Third
# 889       1.0     1.0    male  26.0    0.0    0.0  30.0000        C   First
# 890       0.0     3.0    male  32.0    0.0    0.0   7.7500        Q   Third
#
#        who adult_male deck  embark_town alive  alone
# ...

# %%
data1=pd.read_csv(r"D:\\AI Works\\Machine Learing\\data sets\\archive\\PK COVID-19-30apr.csv")
data1
# Out:
#            Date  Cases  Deaths  Recovered          Travel_history  \
# 0     2/26/2020      1       0          0                   China
# 1     2/26/2020      2       0          0             Iran/Taftan
# 2     2/29/2020      1       0          0                   China
# 3     2/29/2020      1       0          0             Iran/Taftan
# 4      3/2/2020      1       0          0             Iran/Taftan
# ...         ...    ...     ...        ...                     ...
# 1151  4/30/2020     34       0          0  Local - Social Contact
# 1152  4/30/2020      2       0          0  Local - Social Contact
# 1153  4/30/2020     75       0          0  Local - Social Contact
# 1154  4/30/2020      6       0          0  Local - Social Contact
# 1155  4/30/2020      1       0          0  Local - Social Contact
#
#                          Province          City
# 0     Islamabad Capital Territory     Islamabad
# 1                           Sindh       Karachi
# ...
